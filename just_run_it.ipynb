# %% [markdown]
# This script is to run the notebook headless and export it to a PDF and HTML. It will **ONLY** run on Ubuntu

# %%
! sudo apt update
! sudo apt install screen -y

# %%
! bash ./run_headless.sh
# Out:
# ...
# ^C
